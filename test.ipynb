# %%
import h5py
import numpy as np

# %%
train_stare = h5py.File("config_0 (1).h5", 'r')

# %%
print(list(train_stare.keys()))
# Out:
# ['data', 'labels', 'metadata']

# %%
train_stare["data"]
# Out:
# <HDF5 dataset "data": shape (2071247, 5), type "<f4">

# %%
print(list(train_stare["data"][:5]))
# Out:
# [array([ 1.13121195e+05,  1.25982617e+03,  1.01310408e+00,  4.88245850e+01,
#        -1.04486076e+02], dtype=float32), array([ 1.1412438e+05,  1.2800126e+03,  9.8515636e-01,  4.8425041e+01,
#        -1.0353572e+02], dtype=float32), array([ 1.1687204e+05,  1.2399819e+03,  9.7106987e-01,  4.9061420e+01,
#        -9.8876312e+01], dtype=float32), array([ 1.5061847e+05,  1.2599124e+03,  4.9885101e+00,  4.8423901e+01,
#        -1.2422595e+02], dtype=float32), array([ 1.5461919e+05,  1.2801014e+03,  5.0102391e+00,  4.8751350e+01,
#        -1.1708577e+02], dtype=float32)]

# %%
print(list(train_stare["labels"][:5]))
# Out:
# [array([82], dtype=int8), array([82], dtype=int8), array([82], dtype=int8), array([82], dtype=int8), array([82], dtype=int8)]

# %%
list(train_stare["metadata"])
# Out:
# ['feature_names', 'receiver', 'transmitters']

# %%
list(train_stare["metadata"]["feature_names"][:5])
# Out:
# [np.bytes_(b'ToA'),
#  np.bytes_(b'Frequency'),
#  np.bytes_(b'PulseWidth'),
#  np.bytes_(b'AoA'),
#  np.bytes_(b'Amplitude')]

# %%
list(train_stare["metadata"]["receiver"])
# Out:
# ['dwell_centres_mhz', 'dwell_times_s', 'freq_range_mhz', 'start_position_km']
